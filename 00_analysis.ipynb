# %% [markdown]
# ## Analysis of 3x3

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from utils import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Compute all stats by per possession

# %%
dict_men_19 = pd.read_excel("https://fiba3x3cdn.blob.core.windows.net/documents/Statistics/2019/WorldTour/FIBA_3x3_Pro_Circuit_Stats_2019_update04-12-2020.xlsx", None)
dict_men_19.keys()
# Out:
# dict_keys(['Players', 'Team'])

# %%
df_men_19_team = dict_men_19['Team']
df_men_19_players = dict_men_19['Players']

df_men_19_team.head()
# Out:
#         Team  GP   PTS      PTSPG  SEFF    SVAL  WBL  HGL     HGLPG  PT1  ...  \
# 0   Novi Sad  76  1493  19.644737  0.64   955.5   50  622  8.184211  765  ...
# 1  NY Harlem  76  1468  19.315789  0.58   851.4   42  630  8.289474  823  ...
# 2      Liman  89  1737  19.516854  0.62  1076.9   50  654  7.348315  897  ...
# 3     Šakiai  52   974  18.730769  0.59   574.7   23  343  6.596154  475  ...
# 4   Edmonton  55  1017  18.490909  0.59   600.0   25  330  6.000000  537  ...
#
#    OREB  DREB   TO      TOPG   TF      TFPG  TFA     TFAPG      POSPG  \
# 0   302   837  345  4.539474  512  6.736842  578  7.605263  33.289474
# 1   544   879  351  4.618421  412  5.421053  509  6.697368  37.078947
# 2   483   995  430  4.831461  642  7.213483  651  7.314607  34.966292
# 3   331   669  221  4.250000  311  5.980769  340  6.538462  35.153846
# 4   292   657  259  4.709091  321  5.836364  370  6.727273  34.781818
#
#    PTA2_FGA
# 0  0.343831
# 1  0.315500
# 2  0.393238
# 3  0.421084
# 4  0.321886
#
# [5 rows x 38 columns]

# %%
df_men_19_team.GP * df_men_19_team.POSPG
df_men_19_team.columns
df_men_19_team.eval('BS.sum() / TF.sum()')
advanced_stats(df_men_19_team)
# Out:
#           Team  GP   PTS      PTSPG  SEFF    SVAL  WBL  HGL     HGLPG  1PTM  \
# 0     Novi Sad  76  1493  19.644737  0.64   955.5   50  622  8.184211   765
# 1    NY Harlem  76  1468  19.315789  0.58   851.4   42  630  8.289474   823
# 2        Liman  89  1737  19.516854  0.62  1076.9   50  654  7.348315   897
# 3       Šakiai  52   974  18.730769  0.59   574.7   23  343  6.596154   475
# 4     Edmonton  55  1017  18.490909  0.59   600.0   25  330  6.000000   537
# ..         ...  ..   ...        ...   ...     ...  ...  ...       ...   ...
# 118  ZhongGang   2    29  14.500000  0.64    18.6    0   12  6.000000    16
# 119  Changzhou   2    31  15.500000  0.48    14.9    0    6  3.000000    18
# 120     Saigon   2    29  14.500000  0.63    18.3    0   13  6.500000    11
# 121     Yunlin   2    27  13.500000  0.61    16.5    0    4  2.000000    11
# 122       Rome   2    24  12.000000  0.36     8.6    0    8  4.000000    17
#
#      ...    TFAPOS     TFPOS      TOTF      BSTF     TOTFA     TFTFA  \
# 0    ...  0.228458  0.202372  0.673828  0.193359  0.596886  0.885813
# 1    ...  0.180625  0.146203  0.851942  0.286408  0.689587  0.809430
# 2    ...  0.209190  0.206298  0.669782  0.116822  0.660522  0.986175
# 3    ...  0.185996  0.170131  0.710611  0.151125  0.650000  0.914706
# 4    ...  0.193413  0.167799  0.806854  0.143302  0.700000  0.867568
# ..   ...       ...       ...       ...       ...       ...       ...
# 118  ...  0.203704  0.222222  0.833333  0.083333  0.909091  1.090909
# 119  ...  0.164557  0.189873  1.000000  0.200000  1.153846  1.153846
# 120  ...  0.074074  0.185185  0.900000  0.100000  2.250000  2.500000
# 121  ...  0.094340  0.150943  1.125000  0.000000  1.800000  1.600000
# 122  ...  0.192308  0.217949  0.941176  0.058824  1.066667  1.133333
#
#        FTATFA   FTESTFA    FTMTFA   FTESFTA
# 0    0.638408  0.230104  0.453287  0.360434
# 1    0.524558  0.147348  0.332024  0.280899
# 2    0.565284  0.196621  0.368664  0.347826
# 3    0.517647  0.155882  0.355882  0.301136
# 4    0.575676  0.172973  0.405405  0.300469
# ..        ...       ...       ...       ...
# 118  0.545455  0.090909  0.454545  0.166667
# 119  0.461538  0.000000  0.230769  0.000000
# 120  1.000000  0.250000  0.500000  0.250000
# 121  0.200000  0.000000  0.000000  0.000000
# 122  0.666667  0.266667  0.333333  0.400000
#
# [123 rows x 65 columns]

# %%
season_stats(df_men_19_team, 2019)
#df_men_19_team
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/scope.py", line 197, in resolve
#     return self.resolvers[key]
#   File "/usr/local/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/lib/python3.10/collections/__init__.py", line 986, in __getitem__
#     return self.__missing__(key)            # support subclasses that define __missing__
#   File "/usr/local/Cellar/python@3.10/3.10.6_1/Frameworks/Python.framework/Versions/3.10/lib/python3.10/collections/__init__.py", line 978, in __missing__
#     raise KeyError(key)
# KeyError: 'sum'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/scope.py", line 208, in resolve
#     return self.temps[key]
# KeyError: 'sum'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 666, in visit_Call
#     res = self.visit(node.func)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 549, in visit_Name
#     return self.term_type(node.id, self.env, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/ops.py", line 98, in __init__
#     self._value = self._resolve_name()
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/ops.py", line 115, in _resolve_name
#     res = self.env.resolve(self.local_name, is_local=self.is_local)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/scope.py", line 213, in resolve
#     raise UndefinedVariableError(key, is_local) from err
# pandas.core.computation.ops.UndefinedVariableError: name 'sum' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/2s/9_wqwym166ddtr527wj0f93h0000gn/T/ipykernel_4041/171510710.py", line 1, in <cell line: 1>
#     season_stats(df_men_19_team, 2019)
#   File "/Users/x/Documents/GitHub/analysis/utils.py", line 84, in season_stats
#     list_tuple_season_stat.append( ('POS_ESTIMATE', df_teams['1PTM'].sum() + df_teams['2PTM'].sum() + df_teams.eval('TO.sum() + DREB.sum() + (1-FTES.sum()/FTA,sum())*FTM.sum()') ) )
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/frame.py", line 4240, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/eval.py", line 350, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 811, in __init__
#     self.terms = self.parse()
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 830, in parse
#     return self._visitor.visit(self.expr)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 421, in visit_Module
#     return self.visit(expr, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 424, in visit_Expr
#     return self.visit(node.value, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 536, in visit_BinOp
#     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 458, in _maybe_transform_eq_ne
#     right = self.visit(node.right, side="right")
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 536, in visit_BinOp
#     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 456, in _maybe_transform_eq_ne
#     left = self.visit(node.left, side="left")
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 565, in visit_List
#     name = self.env.add_tmp([self.visit(e)(self.env) for e in node.elts])
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 565, in <listcomp>
#     name = self.env.add_tmp([self.visit(e)(self.env) for e in node.elts])
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py", line 670, in visit_Call
#     res = FuncNode(node.func.id)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/pandas/core/computation/ops.py", line 619, in __init__
#     raise ValueError(f'"{name}" is not a supported function')
# ValueError: "sum" is not a supported function
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 1993, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/stack_data/core.py", line 699, in lines
#     pieces = self.included_pieces
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/stack_data/core.py", line 647, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/stack_data/core.py", line 626, in executing_piece
#     return only(
#   File "/Users/x/Library/Caches/pypoetry/virtualenvs/analysis-grMAaxIw-py3.10/lib/python3.10/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %% [markdown]
# ### Piet Van Hasselt Schick Cup 2020 offense outcome by possession
#
# checkball 0.5-0.6 PPP from Schick cup 2020 and analysis of 2019 World cup men's

# %%
df_schickcup20 = pd.DataFrame(columns=['1PT', '1PTA', '2PT', '2PTA', 'FT', 'FTA'], index = ['transition','checkball','oreb'],
                            data = [[322,553, 246, 762, 76, 118],[121,191,52,203,12,21],[85,146,19,59,15,19]])
df_schickcup20
# Out:
#             1PT  1PTA  2PT  2PTA  FT  FTA
# transition  322   553  246   762  76  118
# checkball   121   191   52   203  12   21
# oreb         85   146   19    59  15   19

# %%
offense = 'transition'
PPP_tran = (df_schickcup20.loc[offense,'1PT'] + 2*df_schickcup20.loc[offense,'2PT'])/(df_schickcup20.loc[offense,'1PTA'] + df_schickcup20.loc[offense,'2PTA'])
offense = 'checkball'
PPP_check = (df_schickcup20.loc[offense,'1PT'] + 2*df_schickcup20.loc[offense,'2PT'])/(df_schickcup20.loc[offense,'1PTA'] + df_schickcup20.loc[offense,'2PTA'])
offense = 'oreb'
PPP_oreb = (df_schickcup20.loc[offense,'1PT'] + 2*df_schickcup20.loc[offense,'2PT'])/(df_schickcup20.loc[offense,'1PTA'] + df_schickcup20.loc[offense,'2PTA'])
PPP_tran_oreb = (df_schickcup20.loc['transition','1PT'] + df_schickcup20.loc['oreb','1PT'] + 2* df_schickcup20.loc['transition','2PT']+ 2*df_schickcup20.loc['oreb','2PT'])/(df_schickcup20.loc['transition','1PTA'] + df_schickcup20.loc['transition','2PTA'] + df_schickcup20.loc['oreb','1PTA'] + df_schickcup20.loc['oreb','2PTA'])

PPP_tran, PPP_check, PPP_oreb, PPP_tran_oreb
# Out:
# (0.6190114068441065, 0.5710659898477157, 0.6, 0.6164473684210526)
